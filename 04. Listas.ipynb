# %% [markdown]
# # Listas
#
# En este JNB se revisará el tema de Listas

# %%
numeros_primos = [2,3,5,7]
planets = ['Mercury', 'Venus', 'Earth']
# Out:
# [2, 3, 5, 7]

# %% [markdown]
# Representar juegos de cartas

# %%
manos = [
    ['J', 'Q', 'K'],
    ['2', '2', '2'],
    ['6', 'K', 'Q']
]

# %%
mis_cosas_favoritas = [5, "nose", help]
